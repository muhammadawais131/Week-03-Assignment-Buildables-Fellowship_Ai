# %% [markdown]
# #    *** Week 3 Assignment: Prompt Engineering***

# %% [markdown]
# ### NOTEBOOK # 01 SOLUTION
#
# Prompt Engineering Quiz 💡
#
# Question 1 :
# What is prompting?
#
# Answer: A prompt is giving instruction to ai and giving those instructions in an efficient way to get the best and effective results.
#
# Question 2 : In the following prompt, which part describes the primary task?
# Prompt: “Explain how car batteries work using non-technical language that someone without any mechanical knowledge could understand and interpret.”
#
# Answer : The primary task in this prompt is "Explain how car batteries work" and everything else rather than that is actually modifies the prompt how ai should execute the  primary task.
#
# Question 03 : When you are using a gen AI tool to create a healthy three-course menu that requires a certain number of calories, which prompting element will ensure the menu is more practical?
#
# Answer :So making the prompt more practical it relies on context,Role and constraints so we can add some specific constraints a prep-time,cost,equipment and ingredients.These promting element will make the menu more practical and we can get a realistic and effective output.
#
# Question 04 : Prompting with audio to receive a visual representation is called what?
#
# Answer :A Prompting with audio to receive a visual representation is called Audio to Image generation.
#
# Question 05 : What does a human-in-the-loop approach to prompting emphasize?
#
# Answer :A human-in-the-loop approach emphasizes a person to always check and guides the Ai,A human make sure the Ai answers are correct,authentic,useful and safe.Beacuse a human is there to correct the mistakes of ai and improve the prompt.
#
# Question 06 : When the initial prompt "Create a dataset" is too broad, what should you do to refine it?
#
# Answer : When the prompt "Create a dataset" too broad i will refine it by adding some specific details like a topic,size,format, role and purpose in that way i can get a effiecient result which actually i want.

# %% [markdown]
# ### NOTEBOOK #02  SOLUTION

# %% [markdown]
# Exercise Task 01: Try It Yourself ❗
# Write down your to-do list for today or this week.
# Pick one task where AI could help.
# Example: "Write a follow-up email to my team"
# Open your AI tool and give it this prompt:
# “Draft a professional, friendly email reminding my team about our weekly meeting.”
# Review, edit, and use the result ✅
#
# **Answer**:  **Promt 01**: so help me with writing a letter to our rector about the fess increment my self M.Awais student of bscs 4th semester numl university Islamabad so write a letter in proffsional tone and highlt the subject of letter nedd a compensation with fess i want a ltter upto 5 to 6 lines not more then that chosse a proffesional format for my letter kepp the wording easy and efficeint.
# Prompt 02 : can you please add some more deatils in the body and re00write the letter kepp the format same
#
# Final Output : Subject: Request for Fee Compensation Due to Semester Fee Increment
#
# Respected Rector,
#
# I am M. Awais, a student of BSCS 4th semester at NUML University, Islamabad. I respectfully write to express my concern regarding the recent increase in semester fees. The rise has created a financial challenge for me and my family, making it difficult to continue my studies smoothly. I kindly request your consideration for a fee compensation or relaxation, as this support would enable me to focus on my academic progress without financial stress. Your assistance in this matter will be deeply appreciated.
#
# Sincerely,
# M. Awais
# BSCS 4th Semester
# NUML University, Islamabad

# %% [markdown]
# Exercise: Try It Yourself ❗
# Think of an email you need to write (e.g., to your team, customers, or a client).
# Use the prompt framework:
# Persona: Who are you?
# Context: What’s happening?
# Task: What do you want the email to do?
# Specificity: Add tone, format, details.
# Ask your AI tool to draft the email.
# Then, iterate:
# Change the tone (formal → casual, professional → fun).
# Adjust the audience.
#
# **Answer** : **prompt** : Act as an experienced professional. Write a clear and effective email for me.
#
# Persona: I am a team manager.
# Context: My team just finished a big project ahead of schedule. Everyone worked really hard.
# Task: I want to write an email to my whole team to thank them for their great work and give them an extra day off this Friday as a reward.
# Specificity:
# Tone: Positive, appreciative, and casual.
# Format: Standard email with a subject line.
# -Details: Mention the project name "Project Paypal" and that I am proud of their effort. Tell them to enjoy their long weekend.
#
# **Output** : Here’s a polished email draft you can send to your team:
#
# Subject: Thank You Team – Enjoy a Well-Deserved Long Weekend 🎉
#
# Dear Team,
#
# I want to take a moment to thank all of you for your incredible effort on Project Paypal. Finishing ahead of schedule is no small achievement, and it’s a direct result of the dedication, teamwork, and hard work each of you put in. I am truly proud of what we accomplished together.
#
# As a token of appreciation, I’m giving everyone an extra day off this Friday. Please take this time to relax and enjoy a long weekend — you’ve certainly earned it!
#
# Great job, team, and here’s to many more successes ahead.
#
# Best,
# Muhammad Awais

# %% [markdown]
# Exercise: Try It Yourself ❗
# Practice Tone & Style Prompting
#
# Pick a short text you’ve written (an email, a report, or a social post).
# Rewrite your prompt to specify tone and style.
# Example: “Make this LinkedIn post sound inspirational, like a TED speaker motivating professionals.”
# Run it through your AI tool.
# Iterate: Ask for a new version in a different tone (funny, formal, academic, casual).
# Compare the results — which version feels most effective for your audience?
#
# **Answer : Prompts  01: ** please Rewrite the email to make it sound more inspirational and motivational . Keep all the key information (thanking the team, Project Paypal, the extra day off this Friday) same  but change the style to match the tone.
#
# **OUTPUT** :  Subject: Celebrating Our Success on Project Paypal 🚀
#
# Dear Team,
#
# What we achieved together on Project Paypal is nothing short of inspiring. Finishing ahead of schedule is a clear sign of your commitment, creativity, and teamwork. Each of you went above and beyond, and I couldn’t be prouder to lead such a dedicated group of professionals.
#
# To celebrate this milestone, I’m giving everyone an extra day off this Friday. Use it to recharge, spend time with loved ones, and enjoy a well-earned long weekend.
#
# This is just the beginning — our success on this project shows what’s possible when we work together with focus and passion. Let’s carry this energy forward into everything we do.
#
# With gratitude and pride,
# [Your Name]
#
# **Prompt 02 **: make the new version of this email whcih sound little bit funy and inspirational,motivational also the tone will stay prifessional.
#
# **OUTPUT : ** Perfect — here’s a professional but slightly funny, inspirational, and motivational version of your email. It keeps the balance between humor, professionalism, and appreciation:
#
# Subject: Project Paypal Victory – Time to Recharge ⚡
#
# Dear Team,
#
# You did it — Project Paypal wrapped up ahead of schedule! That’s not just good, it’s legendary. Your hard work, late nights, and unstoppable teamwork made this happen, and I’m genuinely proud to call you my team.
#
# As a reward (and because coffee alone can’t fuel greatness forever), I’m giving everyone an extra day off this Friday. Take the time to relax, recharge, and maybe even remember what sunlight looks like. 🌞
#
# This win proves what we can achieve when we bring our best — and have a little fun along the way. Let’s keep this momentum alive for what’s next!
#
# Cheers,
# Muhammad Awais

# %% [markdown]
# Exercises : Try It Yourself ❗
#
# Exercise 1: Icebreakers
#
# **Prompt : ** generate 3 creative icebreakers for a new teammate who loves basketball and photography.
#
# **OUTPUT : ** Here are 3 fun and creative icebreakers tailored for a teammate who loves basketball and photography:
#
# Photo Dunk Challenge
# 👉 “If you had to capture a perfect photo of a slam dunk, would you rather be under the basket risking the ball flying at you, or up in the stands with the wide-angle view? Why?”
# (Gets them talking about both passions in a playful way.)
#
# Team Roster Selfie
# 👉 “Imagine our team as a basketball squad — what position would you assign yourself, and can you snap a quick creative selfie that matches that role?”
# (Blends team bonding, basketball, and photography.)
#
# Slam Dunk or Snapshot?
# 👉 “You can only choose one: hitting a game-winning buzzer beater or capturing a once-in-a-lifetime photo that goes viral worldwide. Which one are you taking, and why?”
# (Sparks fun debate and shows personality.)

# %% [markdown]
# Exercise 2: Product Launch
#
# **Prompt : **  Hey i am launching a new mobile fitness app
# Define a 6-month launch timeline.
# Suggest 3 pre-launch buzz ideas.
#
# **OUTPUT :**  Here’s a 6-month launch plan for your mobile fitness app + 3 pre-launch buzz ideas to build excitement:
#
# 📅 6-Month Launch Timeline
#
# Month 1: Research & Planning
#
# Finalize app features, target audience, and unique selling points (USP).
#
# Define KPIs (downloads, retention, engagement).
#
# Set up project management + marketing calendar.
#
# Month 2: Branding & Early Community Building
#
# Create brand identity (logo, colors, tone).
#
# Build social media accounts & a simple landing page with email signup.
#
# Identify fitness influencers or micro-creators for partnerships.
#
# Month 3: Beta Development & Testing
#
# Release private beta to 50–100 testers (friends, early adopters, fitness enthusiasts).
#
# Collect feedback on usability, bugs, and workout experience.
#
# Share behind-the-scenes development updates on socials.
#
# Month 4: Content & Buzz Creation
#
# Start producing blog posts, short fitness reels, and workout tips.
#
# Tease unique features (e.g., “Your workout, your AI coach”).
#
# Secure early media/PR outreach with fitness magazines & blogs.
#
# Month 5: Pre-Launch Campaign
#
# Launch waitlist with referral rewards (free premium trial for signups).
#
# Begin influencer teaser campaigns (“Something new is coming to fitness…”).
#
# Announce countdown (30 days to go).
#
# Month 6: Official Launch 🚀
#
# Launch app in app stores.
#
# Run paid ads + organic campaigns on social media.
#
# Host a live launch event (Instagram Live, TikTok, or in-person fitness class).
#
# Track KPIs and gather user feedback for updates.
#
# 🔥 3 Pre-Launch Buzz Ideas
#
# Fitness Challenge with a Twist
#
# Run a free 7-day challenge (e.g., “7 Days, 7 Moves”) where users sign up on your landing page.
#
# Encourage sharing progress on social media with a branded hashtag.
#
# Behind-the-Scenes Sneak Peeks
#
# Share short clips of the app in action (without giving everything away).
#
# Include “exclusive insider” updates for waitlist subscribers.
#
# Founding Member Rewards
#
# Offer the first 500 signups a special “Founding Member Badge” inside the app + 1 free month premium.
#
# Creates exclusivity and early adoption hype.

# %% [markdown]
# Exercise 3: Global Audience Twist
# **Prompt : ** hey can you please adjust the ideas for  global audience for my app .
#
# OUTPUT :  Got it 👍 Since your fitness app is for a global audience, we’ll adjust the timeline and pre-launch buzz ideas to make sure they work worldwide, not just locally.
#
# 🌍 Adjusted 6-Month Global Launch Timeline
#
# Month 1: Global Market Research & Localization Prep
#
# Study fitness trends in key regions (e.g., HIIT in the U.S., yoga in India, functional training in Europe).
#
# Define localization strategy (languages, units: lbs/kg, miles/km).
#
# Research culturally relevant influencers across regions.
#
# Month 2: Branding for Global Appeal
#
# Create brand identity that’s neutral but energetic (colors/symbols that work globally).
#
# Launch social pages on globally popular platforms (Instagram, TikTok, YouTube) + regionals (Weibo, WhatsApp groups, etc.).
#
# Start a multilingual landing page with waitlist.
#
# Month 3: International Beta Testing
#
# Invite testers from different countries (North America, Europe, Asia).
#
# Test usability, translations, and cultural acceptance (e.g., modesty in workout visuals).
#
# Gather global testimonials to use later in marketing.
#
# Month 4: Global Content Creation & Partnerships
#
# Partner with micro-influencers from multiple countries.
#
# Create universal content (short workouts, motivational quotes) and local ones (region-specific diet/workout tips).
#
# Build PR outreach for international fitness blogs + YouTube reviewers.
#
# Month 5: Worldwide Pre-Launch Campaign
#
# Launch global waitlist with region-specific perks (discounts, premium trial, cultural badges).
#
# Start influencer teaser campaigns worldwide.
#
# Begin countdown in multiple languages.
#
# Month 6: Official Global Launch 🚀
#
# Release app in App Store + Google Play worldwide.
#
# Run ads tailored by region (different workout visuals, languages).
#
# Host a “Global Fitness Day” virtual live event with workouts streamed across time zones.
#
# Track KPIs globally (downloads per country, active users).
#
# 🔥 3 Pre-Launch Buzz Ideas (Global Edition)
#
# 🌐 Global Fitness Challenge
#
# A 10-day challenge like “10 Minutes, 10 Countries” where each day features a short workout inspired by a country (e.g., yoga from India, boxing-inspired HIIT from the U.S., dance cardio from Brazil).
#
# Users share progress with a hashtag like #FitTogetherGlobal.
#
# 🎥 “Workout in My City” Campaign
#
# Partner with micro-influencers worldwide to film short workouts in iconic local spots (e.g., lunges in front of Eiffel Tower, pushups on a beach in Rio).
#
# Builds a sense of inclusivity and global vibe.
#
# 🌍 Founding Member World Map
#
# First 1,000 global signups get a special “Founding Member Badge” in the app.
#
# Display a live world map on your landing page showing where early members are joining from.

# %% [markdown]
# ✅ Reflection Question 💡
# How can you use generative AI to spark new ideas in your own projects or workplace?
#
# Answer : I can use generative AI as a creative partner to brainstorm fresh ideas, explore different perspectives, and speed up content creation. It helps me experiment with marketing strategies, designs, or campaign concepts that I might not think of on my own. By quickly generating variations, I can choose the best fit and refine it further. This makes problem-solving and innovation in projects faster and more effective.

# %% [markdown]
# Exercises: Try It Yourself ❗
#
# Exercise 1: Project Tracker
#
# **Answer : ** **Prompt :**  create a project tracker with columns: Task, Owner, Deadline, Status. Add constraints: Each owner should have no more than 2 active tasks.
#
# **OUTPUT :**  Here’s a simple project tracker table with your required columns + the constraint that each owner has no more than 2 active tasks:
#
# 📊 Project Tracker
# Task	Owner	Deadline	Status
# Design app logo	Awais	Sep 25	In Progress
# Build landing page	Awais	Sep 28	Not Started
# Create social media kit	Laiba	Sep 27	In Progress
# Draft press release	Laiba	Sep 30	Not Started
# Beta testing setup	Shaheer	Oct 2	In Progress
# Collect user feedback	Hussain	Oct 5	Not Started
#
# ✅ Constraint Applied
#
# Each owner (Awais, Laiba, Shaheer, Hussain) has no more than 2 active tasks assigned.
#
# “Active” means In Progress or Not Started.

# %% [markdown]
# ### Exercise 2: Event Schedule
#
# **prompt : ** I am planing 3-day conference. please  generate a schedule with:
#
# Columns: Day, Session Title, Speaker, Time.
# Constraint: No speaker should have more than 1 session per day.
#
# ### OUTPUT :  Here’s a 3-day conference schedule with your required columns and the constraint that no speaker has more than 1 session per day:
#
# 📅 Conference Schedule
#
# Day	Session Title	Speaker	Time
#
# Day 1	Opening Keynote: Future of Fitness	Dr. Ayesha	09:00–10:00
# Day 1	Building Global Health Communities	Mr. Khan	11:00–12:00
# Day 1	AI in Personal Training	Ms. Fatima	02:00–03:00
# Day 1	Networking & Panel Discussion	Panel (Multi)	04:00–05:00
#
# Day 2	Nutrition & Lifestyle Balance	Dr. Ahmed	09:00–10:00
# Day 2	Mental Wellness in Fitness	Ms. Sara	11:00–12:00
# Day 2	Designing Engaging Fitness Apps	Mr. David	02:00–03:00
# Day 2	Startup Pitch Showcase	Panel (Multi)	04:00–05:00
#
# Day 3	Emerging Tech in Sports Science	Dr. John	09:00–10:00
# Day 3	Women in Fitness Leadership	Ms. Emily	11:00–12:00
# Day 3	Global Fitness Trends 2025	Mr. Ali	02:00–03:00
# Day 3	Closing Keynote + Awards	Dr. Sophia	04:00–05:00
# ✅ Constraint Applied
#
# Each speaker only appears once per day.
#
# Panels are labeled as multi-speaker, so they don’t break the rule.

# %% [markdown]
# Exercise 3: Team Availability
#
# **Prompt : ** generate a vacation tracker for 8 employees.
#
# Columns: Employee, Vacation Start, Vacation End.
# Constraint: At least 5 employees must be available at all times.
#
# *Answer : * Thought for 8s
#
# Nice — here’s a ready-to-use vacation tracker for 8 employees with the constraint applied: no more than 3 employees on vacation at the same time (so at least 5 available).
#
# Employee	Vacation Start	Vacation End
#
# Awais	2025-10-06	2025-10-10
# Laiba	2025-10-08	2025-10-12
# Zia	2025-10-10	2025-10-14
# Shaheer	2025-10-20	2025-10-24
# Hussain	2025-11-03	2025-11-14
# Maria	2025-11-10	2025-11-14
# David	2025-11-17	2025-11-21
# Emily	2025-12-01	2025-12-12
# Constraint check
#
# The busiest overlap day is 2025-10-10 (Awais, Laiba, Zia) → 3 on leave → 5 available.
#
# No date has more than 3 overlapping vacations, so the rule “at least 5 employees available at all times” is satisfied.
#
# Quick spreadsheet validation (optional)
#
# To prevent assigning a new vacation that would break the rule, use this validation formula in Google Sheets / Excel (replace ranges with your actual table ranges).
# For a proposed start in cell S and end in E:
#
# =SUMPRODUCT( --( ($B$2:$B$9 <= E) * ($C$2:$C$9 >= S) ) ) <= 3
#
#
# If the result is TRUE the new booking is allowed; FALSE means it would exceed the max allowed concurrent vacations.

# %% [markdown]
# ✅ Reflection Question
#
# How could you use AI to organize recurring tasks (like meetings, deadlines, or resources) at your workplace?
#
# **Answer : ** AI can play a vital role in managing recurring workplace tasks by automating scheduling, tracking, and reminders.It can optimize meeting times, send timely alerts for deadlines, and allocate resources more efficiently.Such automation reduces human error and saves time, while ensuring consistency and accountability. By streamlining routine activities, AI allows employees to focus on higher-value and creative work.

# %% [markdown]
# # Exercises: Try It Yourself ❗
#
# Exercise 1: Speaker-based Minutes
#
# **Prompt : ** Act as an expert executive assistant. Convert the following meeting transcript into clear, structured, and professional meeting minutes.
#
#  Instructions:
# 1.  Organize by speaker. Each speaker should have their own section.
# 2.  Summarize key points. Under each speaker, provide 2-3 bullet points that concisely capture their main contributions, decisions, or ideas.
# 3.  Identify action items clearly. For any task mentioned, extract it and mark it with
#  ✅ ACTION: Clearly state the owner and the deadline (if mentioned).
# 4.  Use a professional tone.
#
# Meeting Transcript:
# Meeting: Website Redesign
# People: Anna, Ben, Chloe
# Anna: Let's kick things off. The goal is to finalize the homepage wireframes. Ben, can you show what you have?
# Ben: Yeah, I've got three options. I think Option B is the strongest because it simplifies the user journey. I can email them out after the meeting.
# Chloe: I like Option B too, but we need to check if it aligns with the new brand colors. I'll talk to the design team about that.
# Anna: Perfect. Chloe, please report back by Thursday. Ben, send the wires to the whole team. Let's reconvene on Friday to make a final decision.
#
# **OUTPUT : ** Here are the structured Meeting Minutes in a professional format:
#
# Meeting Minutes
#
# Meeting: Website Redesign
# Date: [Insert Date]
# Attendees: Anna, Ben, Chloe
#
# Anna
#
# Opened the meeting and set the goal: finalize homepage wireframes.
#
# Assigned follow-up tasks to Ben and Chloe.
#
# Confirmed next meeting on Friday for a final decision.
#
# ✅ ACTION: Chloe to report back on brand color alignment by Thursday.
# ✅ ACTION: Ben to share wireframe options with the team via email.
#
# Ben
#
# Presented three wireframe options.
#
# Recommended Option B for its simplified user journey.
#
# Agreed to circulate the wireframes after the meeting.
#
# ✅ ACTION: Ben to email wireframe options to the entire team.
#
# Chloe
#
# Expressed preference for Option B.
#
# Highlighted the need to ensure brand color alignment.
#
# Agreed to follow up with the design team on color consistency.
#
# ✅ ACTION: Chloe to consult with design team and provide feedback by Thursday.
#
# Next Meeting: Friday – Final decision on homepage wireframes.

# %% [markdown]
# ### Exercise 2: Action-Focused Notes
#
# **Prompt : ** Create meeting minutes that focus only on action items.
# Format each entry as: Action Item, Responsible Person, Deadline.
#
# **OUTPUT : ** Here’s a clean Action-Only Meeting Minutes format based on your transcript:
#
# Meeting Minutes – Action Items Only
#
# Action Item: Email homepage wireframe options to the team
# Responsible Person: Ben
# Deadline: [Not specified – send immediately after meeting]
#
# Action Item: Consult design team on brand color alignment for Option B and report back
# Responsible Person: Chloe
# Deadline: Thursday
#
# Action Item: Reconvene team to finalize decision on homepage wireframes
# Responsible Person: Anna (Organizer)
# Deadline: Friday

# %% [markdown]
# ### Exercise 3: Thematic Notes
#
# **Prompt :**  Group meeting minutes into sections based on topics discussed.
# For each section, summarize key decisions, and list assigned action items.
#
# **OUTPUT : ** Here’s a topic-based version of the meeting minutes for clarity and professionalism:
#
# Meeting Minutes – Website Redesign
#
# Date: [Insert Date]
# Attendees: Anna, Ben, Chloe
#
# 1. Homepage Wireframes
#
# Discussion:
#
# Ben presented three homepage wireframe options.
#
# Option B was highlighted as the strongest for simplifying the user journey.
#
# Team leaned toward Option B, pending brand color alignment.
#
# Decisions:
#
# Option B is the preferred design direction.
#
# Final confirmation will be made after checking brand colors.
#
# Action Items:
#
# ✅ Ben to email homepage wireframe options to the entire team. (Deadline: after meeting)
#
# ✅ Chloe to consult with the design team on color alignment and report back. (Deadline: Thursday)
#
# 2. Next Steps & Timeline
#
# Discussion:
#
# Anna emphasized the importance of timely follow-up.
#
# Agreed to reconvene later in the week.
#
# Decisions:
#
# Final decision meeting scheduled for Friday.
#
# Action Items:
#
# ✅ Anna to organize follow-up meeting for final approval. (Deadline: Friday)

# %% [markdown]
# **✅ Reflection Question 💡 :** How could AI-generated meeting notes help you improve follow-up and accountability in your workplace?
#
# **Answer : ** AI-generated meeting notes would make it easier for me to keep track of tasks and deadlines. Since responsibilities are clearly written, I can follow up more confidently and make sure everyone stays accountable.

# %% [markdown]
# ### Exercises: Try It Yourself ❗
#
# ## Exercise 1: Outline Summary
#
# **Prompt : ** Summarize this document into a bulleted outline of no more than 10 points.
#
# **OUTPUT : ** Of course. Here is a concise, 10-point summary of the article.
#
# Summary: Ambient Computing
#
# Definition: Technology that seamlessly blends into the environment, becoming invisible to the user.
#
# Goal: To provide services without requiring active interaction with a device.
#
# Core Enabler: The convergence of IoT sensors, ubiquitous connectivity, and AI.
#
# Key Feature: Systems anticipate needs and act proactively based on context.
#
# Common Examples: Smart thermostats, voice assistants, and personalized health tracking.
#
# User Benefit: Creates a continuous, uninterrupted flow of assistance in daily life.
#
# Major Challenge: Significant privacy concerns due to constant data collection.
#
# Major Challenge: A lack of universal standards causing interoperability issues between devices.
#
# Major Challenge: Risk of a digital divide based on who can afford the technology.
#
# Future Outlook: A shift away from visible devices to a pervasive, intelligent environment.

# %% [markdown]
# ### Exercise 2: Audience Summary
#
# **Prompt : ** Summarize this document as if explaining it to a high school student.
#
# **OUTPUT : ** Of course! Here is a summary of that article in simple terms.
#
# Ambient Computing Explained Simply
# Imagine technology is like magic—it's all around you, helping you out, but you don't really see how it works. That’s basically ambient computing.
#
# What does that mean?
# It means all your smart devices—like your phone, your speaker (like Alexa or Google Home), your watch, and even your lights—work together quietly in the background to make your life easier. You don’t have to push buttons or open apps for everything; things just happen automatically.
#
# Here’s an example:
#
# Your alarm wakes you up at the perfect time in your sleep cycle.
#
# The lights in your room slowly turn on to mimic a sunrise.
#
# Your coffee starts brewing by itself because it knows you’re awake.
#
# All of this happens without you telling it to do each step. Cool, right?
#
# How does it work?
# It uses:
#
# Tiny sensors (like in your watch or phone).
#
# The internet (to connect everything).
#
# Artificial intelligence (a smart computer brain that learns your routine).
#
# But there’s a catch:
# Since these devices are always collecting information about you, there are big questions about:
#
# Privacy: Who else can see what you’re doing?
#
# Security: Can hackers get into your devices?
#
# Fairness: Will only people who can afford lots of gadgets get these benefits?
#
# The bottom line:
# Ambient computing isn’t about fancy robots—it’s about technology quietly working together so you can focus on your life, not your devices. The goal is to make tech feel less like a tool and more like a helpful, invisible friend.

# %% [markdown]
# ### Exercise 3: Comparative Summary
#
# **Prompt : ** Summarize this report in two versions:
# 1. Executive summary for leadership.
# 2. Simplified version for frontline employees.
#
# **OUTPUT : ** **1. Executive Summary for Leadership**
#
# To: Leadership Team
#
# From: [Your Name/Dept.]
#
# Date: October 26, 2023
#
# Subject: Strategic Brief on Ambient Computing
#
# Overview:
# Ambient computing represents the next major paradigm shift in technology, moving away from distinct devices toward a seamless, integrated layer of intelligent assistance embedded within the environment itself. It is characterized by technology that is invisible, contextual, and proactive.
#
# Key Drivers & Value Proposition:
# This shift is powered by the convergence of IoT sensors, ubiquitous connectivity (5G/Wi-Fi 6), and advanced AI/ML. The primary value is an unparalleled user experience that drives engagement, customer loyalty, and operational efficiency through automation and predictive support.
#
# Strategic Implications & Opportunities:
#
# Product Development: We must prioritize ecosystem integration, interoperability, and features that leverage contextual awareness.
#
# Customer Experience: This allows for hyper-personalized, frictionless user journeys, creating a significant competitive advantage.
#
# Data Strategy: The model generates vast amounts of behavioral data, presenting opportunities for insights but also requiring robust management.
#
# Critical Risks to Mitigate:
#
# Privacy & Security: The always-on, data-collecting nature of ambient systems presents severe privacy challenges and a expanded attack surface for cyber threats.
#
# Interoperability: A lack of industry-wide standards could lead to fragmented ecosystems, locking customers into single vendors.
#
# Equity: Potential exists for a new "digital divide," where only premium users access these benefits, impacting brand perception and inclusivity.
#
# Recommendation:
# Leadership should treat ambient computing as a strategic priority. We must invest in R&D, establish a clear data ethics policy, and explore partnerships to ensure our products and services are compatible with this evolving landscape.
#
#
#
# 2. Simplified Version for Frontline Employees **bold text**
#
# Hey Team,
#
# You might have heard the term "ambient computing." Here’s what it means in simple terms and how it might affect our customers and us.
#
# What is it?
#
# Think of it as "invisible technology." It’s all about your smart devices—phones, speakers, watches, home gadgets—working together automatically in the background without you having to constantly tell them what to do.
#
# It’s like magic, but real:
#
# A customer’s lights turn on when they walk into a room.
#
# Their playlist moves seamlessly from their phone to their car speakers.
#
# Their thermostat adjusts itself based on their schedule.
#
# Why it matters for us:
#
# For Customer Support: Customers may have more complex, interconnected issues. Instead of troubleshooting one device, we might need to think about how their entire smart home ecosystem is working together.
#
# For Sales & Advice: Customers will be looking for products that work well with others. Understanding which devices and brands "talk" to each other smoothly will be key.
#
# The Bottom Line: Our goal is to help customers build a seamless, helpful tech environment that makes their lives easier. The better we understand how these devices connect, the better we can serve them.
#
# The big thing to remember: This technology is all about making things easier and more automatic for the user. Our role is to be the friendly experts who help make that happen.

# %% [markdown]
# **✅ Reflection Question 💡 :** How could tailoring summaries to different audiences (executives, clients, students) improve understanding and decision-making in your work?
#
# **Answer : **  Tailoring summaries ensures the information is relevant and accessible, eliminating unnecessary details for faster, more informed decisions. It aligns the message with the audience's priorities, increasing engagement and driving appropriate action. This approach builds trust and ensures everyone operates from the same core understanding, tailored to their specific role and needs.

# %% [markdown]
# ## Practice Advanced Summarization Techniques
#
# ### Exercise
#
# Prompt : first give me a Broad overview  just in 1 paragraph
#
# Answer : Of course. Here is a broad, one-paragraph overview of the article:
#
# Quantum computing represents a fundamental shift from classical computing by leveraging the principles of quantum mechanics through qubits, which can exist in multiple states simultaneously (superposition) and be deeply interconnected (entanglement). This allows quantum computers to process complex problems—like molecular simulation for drug discovery, global logistics optimization, and cryptography-breaking—at speeds impossible for even the most powerful supercomputers today. However, practical application remains challenging due to the extreme fragility of qubits and difficulties in maintaining stable, large-scale systems. While still evolving, quantum computing holds transformative potential for targeted industries, promising breakthroughs in science, security, and AI through a future hybrid model of classical and quantum collaboration.
#
# **Prompt : ** A Shorter summary  3  in bullet points
#
# Answer : Summary of Quantum Computing
# Uses Qubits, Not Bits: Unlike classical computers (which use 0s and 1s), quantum computers use quantum bits or qubits. These can be in multiple states at once (superposition) and be deeply linked (entanglement), allowing them to solve certain complex problems exponentially faster.
#
# Solves Specific Complex Problems: Its power is targeted at fields like simulating molecules for drug discovery, optimizing global supply chains, and breaking current encryption methods, which are impractical for even the best supercomputers.
#
# Still in Development: Building practical quantum computers is a major challenge due to the extreme fragility of qubits, which require near-absolute zero temperatures and isolation from all interference. We are currently in the early, error-prone stages of this technology.
#
# **Prompt : **give me a Single sentence (main trend/insight).
#
#  **Answer : ** Quantum computing is transitioning from theoretical research to early practical application, poised to revolutionize fields like materials science and cryptography by solving problems beyond the reach of classical computers, though significant technical hurdles in stability and scaling remain.

# %% [markdown]
# ## NOTEBOOK # 03 SOLUTIONS
#
#
# 📝 Questions for Reflection
#
# Question 01 : How is prompt chaining similar to solving a jigsaw puzzle?
#
# Answer : Prompt chaining is like solving a jigsaw puzzle because each prompt is a piece that connects to the next.When combined they build the full picture or solution step by step.
#
# Question 02 :What’s the main difference between iteration and chaining?
#
# Answer : Iteration means improving the same prompt repeatedly until you get the best result, while chaining means using the output of one prompt as the input for the next to reach a bigger goal.
#
# Question 03: Why might prompt chaining be more effective than asking AI one big question?
#
# Answer : Prompt chaining can be more effective because it breaks a complex task into smaller steps making it easier for Ai to stay focused and accurate.This way, each step builds on the last, reducing confusion and improving the final result.
#
# Question 04 : How can the context window of an AI model affect your chaining strategy?
#
# Answer : The context window limits how much information an Ai can remember at once.If our chain is too long,Earlier details may get lost.So we need to summarize or pass only the most important outputs forward to keep the chain effective.

# %% [markdown]
# ### Exercises : Try It Yourself ❗
# ### Exercise 1: Email Catch-Up
#
# 01. Summarizes all your emails.
#
# Answer : Summarize the following emails I received while I was away. Group them by topic and keep the summaries brief.
#
#
# 02 . Highlights urgent tasks.
#
# Answer : From the summarized emails, list all urgent or time-sensitive tasks, including any deadlines mentioned.
#
# 03 . Suggests solutions for the most critical issue.
#
# Answer :From the urgent tasks,identify the single most critical issue and suggest 2–3 possible solutions with pros and cons for each.:

# %% [markdown]
# ### Exercise 2: Research Assistant
#
#  01 : Generate Outline
#
#  Create a structured outline for my research paper on [insert topic]. Include main sections and key points for each.
#
# 02 : Suggest Key Studies
#
# “From the outline, recommend three important academic studies or sources I should cite, and briefly explain why each is relevant.”
#
# 03 : Draft Introduction
#
# Using the outline and the suggested studies, draft a short introduction (around 150–200 words) that clearly sets context and shows the paper’s significance.

# %% [markdown]
# Exercise 3: Business Idea Pitch
#
#  01 : One-Sentence Pitch
#
# Create a concise one-sentence pitch for a new mobile app idea that highlights its purpose and value.
#
# 02 : Target Audience Description
#
# Expand the one-sentence pitch into a short paragraph that clearly describes the target audience and their needs.
#
# 03 :  Pitch Deck Outline
#
# Generate a three-slide pitch deck outline for investors based on the app idea and target audience, covering (1) Problem, (2) Solution, (3) Market Opportunity.

# %% [markdown]
# ### Exercise: Try It Yourself ❗
#
# Complex Decision with CoT **bold text**
#
# Scenario :
# Allocating a company’s annual $50,000 training budget across three employee development programs.
#
# Step 1 : Initial Prompt
# “Help me allocate a $50,000 annual training budget across three programs: technical upskilling, leadership training, and wellness initiatives. Explain your reasoning step-by-step.”
#
# Step 2 : Review & Tweak Prompt (adding constraints)
# If the output feels too generic, refine the prompt:
# “Help me allocate a $50,000 annual training budget across technical upskilling, leadership training, and wellness initiatives. At least 40% should go to technical upskilling. Assume we have 200 employees, most of them junior staff. Explain your reasoning step-by-step.”
#
# 📌 Key Takeaway
# Chain-of-thought (CoT) prompting makes the AI’s reasoning process transparent, so you can trust and adjust the decision-making process with confidence.

# %% [markdown]
# ### Exercise: Try It Yourself ❗
# Pick a creative or abstract problem (e.g., designing a campaign, brainstorming product features).
#
# Write a prompt asking AI to explore multiple solutions and evaluate them.
#
# Example: “Propose three marketing strategies for a new app launch. Evaluate each for cost, reach, and impact.”
#
# Review the output and iterate to refine (e.g., focus on one path or add constraints).

# %% [markdown]
# Exercise: Try It Yourself ❗
# Pick a creative or abstract problem (e.g., designing a campaign, brainstorming product features).
#
# Write a prompt asking AI to explore multiple solutions and evaluate them.
#
# Example: Propose three marketing strategies for a new app launch. Evaluate each for cost, reach, and impact.
#
# Review the output and iterate to refine (e.g., focus on one path or add constraints).
#
# Initial Prompt:
#
# Suggest three unique features for a student productivity app. Evaluate each feature based on ease of implementation, usefulness for students, and potential to stand out in the market.
#
# Refined Prompt (iteration):
# Focus on one standout feature from your suggestions and create a 6-week development roadmap. Assume limited resources (small student team, basic tools) and explain step by step how to build it.

# %% [markdown]
# ### Practice Advanced Prompting Techniques
# Exercises: Try It Yourself ❗
#
# Exercise 1: CoT for Decision-Making
#
# Write a prompt for a work-related decision (e.g., prioritizing tasks, choosing vendors). Ask AI to explain its reasoning step-by-step.
# Example: “Help me choose between two software vendors. Explain your reasoning for each step.”
#
# **Prompt : ** Help me prioritize today’s work tasks. Explain step by step why each task should be higher or lower on the list.
#
# Exercise 2: ToT for Creative Brainstorming
#
# Write a prompt for a creative task (e.g., campaign ideas, product features). Ask AI to propose multiple solutions and evaluate them.
# Example: “Suggest three themes for a company retreat. Evaluate each for engagement and cost.”
#
# **Prompt : ** Suggest three unique marketing ideas for a new fitness app. Evaluate each for creativity, reach, and cost.
#
# Exercise 3: Combine CoT and ToT
#
# Write a prompt that uses ToT to explore options and CoT to refine the best one.
# Example: “Propose three product launch ideas, evaluate them, then provide a step-by-step plan for the best one.
#
# ***Prompt : ***  Propose three outreach strategies for a startup, evaluate them, then give a step-by-step action plan for the best one.
#
# ✅ Reflection Question 💡 :How could CoT and ToT prompting help you solve complex problems or spark creativity in your workplace?
#
# Answer : CoT prompting helps break down complex problems step by step, making decisions clearer and less overwhelming. ToT prompting sparks creativity by generating multiple options and comparing them. Together, they ensure both structured reasoning and innovative thinking, which leads to better problem-solving and more creative solutions at work.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Choose a task where reasoning matters (e.g., budgeting, scheduling).
#
# Write a prompt asking AI to explain its reasoning step-by-step.
#
# Example: “Plan a $5,000 team retreat and explain your reasoning for each expense.”
#
# Review the reasoning and refine the prompt if needed (e.g., add constraints).
#
# **Answer : ** Prompt:
#
# “Create a detailed $5,000 budget for a 20-person team retreat, allocating amounts to venue, travel, food, activities, and contingency — and explain step-by-step the reasoning and trade-offs for each allocation.”
#
# Refined (with constraint): “Same, but prioritize cost-saving (max travel $800) and keep contingency ≤10%; show step-by-step reasoning for every change.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Pick a creative task (e.g., campaign ideas, visual design).
#
# Write a prompt asking AI to propose three distinct solutions and evaluate them.
#
# Example: “Suggest three themes for a product launch event, evaluate each for cost and appeal, and recommend one.”
#
# Follow up by refining the recommended option.
#
# Initial prompt:
# **bold text**
# Suggest three distinct campaign concepts for a new fitness-app launch. For each give a 1-line summary, target audience, estimated cost (low/med/high with rough $), main channels, and expected KPIs — then recommend the best one and why.
#
# **Refinement prompt:**
#
# Take the recommended campaign and produce a 6-week execution plan (assume $10,000 budget, 3-person team): weekly goals, channel tactics, budget breakdown, 8 sample social posts (copy + asset idea), and KPIs to track.

# %% [markdown]
# ### Exercise: Try It Yourself ❗
#
# Choose a complex project (e.g., product launch, training program).
#
# Write a ToT prompt to explore three options.
#
# Write a CoT prompt to refine the best option with step-by-step reasoning.
#
# Answer : **ToT prompt:**
#
# “Propose three distinct strategies for a 12-week product launch (e.g., community-driven prelaunch, B2B pilot + case studies, influencer + paid ads). For each give a 2-line summary, target audience, main activities, estimated cost tier, timeline, and expected KPIs.”
#
# **CoT prompt:**
#
# “Pick the best strategy above for a cash-constrained startup and produce a detailed week-by-week 12-week execution plan — explain step-by-step the reasoning for each week’s priorities, resource allocation, trade-offs, risks, and the metrics to track.

# %% [markdown]
# ### Practice Prompt Chaining
# Exercises: Try It Yourself ❗
#
# Exercise 1: Build a Project Step-by-Step
#
# Pick a multi-step project (e.g., marketing campaign, event planning).
#
# Chain three prompts: outline, expand a section, create an activity/visual.
#
# Example: “Outline a team training program, expand one module, suggest an interactive exercise.”
#
# Prompt 1 (outline):
#
# “Create a 6-week team training program on remote collaboration for 20 people: give weekly module titles, objectives, learning outcomes, required materials, roles, and success metrics.”
#
# Prompt 2 (expand one part):
#
# “Expand Week 3 (Tools & Workflows) into a detailed 90-minute lesson: learning objectives, minute-by-minute agenda, hands-on tasks, slide headings, resources, and assessment methods.”
#
# Prompt 3 (activity/visual):
#
# “Design a 30-minute interactive workshop for Week 3: facilitator script, participant instructions, materials list, time breakdown, expected outcomes, and a simple wireframe/sketch idea for the activity layout.

# %% [markdown]
# ### Exercise 2: CoT for Clarity
# Choose a task requiring logic (e.g., budgeting, scheduling).
#
# Prompt AI to explain its reasoning step-by-step.
#
# Example: “Allocate a $2,000 budget for a team event. Explain your reasoning.”
#
# **Prompt:**
#
# Allocate a $2,000 budget for a 20-person team offsite (venue, travel, food, activities, contingency). Explain step-by-step the reasoning for each allocation, show per-person costs, trade-offs, and one lower-cost alternative.
#
# ### Exercise 3: ToT for Creativity
# Pick a creative task (e.g., branding, content ideas).
# Prompt AI to propose three solutions and evaluate them.
# Example: “Suggest three social media campaign ideas. Evaluate each for engagement.”
#
# **Prompt :** Suggest three social media campaign ideas for a new tech brand. Evaluate each for creativity, engagement, and cost, then recommend the best one
#
# ### Exercise 4: Combine CoT and ToT
# Use ToT to explore options for a project.
#
# **ToT prompt:**
# “Propose three event formats for a product launch; for each give a 1-line summary, target audience, main activities, estimated cost tier, and expected KPIs.
#
# Use CoT to refine the best option with detailed reasoning.
#
# ** COT Prompt :**  Choose the best format above for a cash-constrained startup and produce a week-by-week execution plan with step-by-step reasoning, resource trade-offs, risks, and metrics to track.
#
# **✅ Reflection Question 💡:**
# How could prompt chaining help you simplify a complex project or improve collaboration in your workplace?
#
# Answer : Prompt chaining simplifies complex projects by breaking them into smaller, manageable steps (plan → expand → refine). It also improves collaboration because team members can focus on specific outputs at each stage, ensuring clarity, reducing confusion, and making the workflow more structured and efficient.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Choose a large document (e.g., report, manuscript, or presentation). Write a prompt asking AI to analyze it for key points, gaps, or improvements. Example: “Analyze my 50-page report and summarize the main arguments in bullet points.” Review the output and refine the prompt (e.g., ask for specific feedback on tone or structure).
#
# Initial Prompt: Analyze my 30-page research report and summarize the main arguments, evidence, and conclusions in concise bullet points.
#
# Refined Prompt: Review the same report but focus on gaps in logic, unclear sections, and tone consistency. Suggest improvements for clarity, flow, and persuasiveness.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Pick a time-sensitive task (e.g., email, proposal, or presentation).
# Write a prompt asking AI to draft an outline or initial version.
# Example: “Draft a professional email inviting clients to a product demo. Include date, time, and purpose.”
# Refine the output to match your style or add specific details.
#
# **Initial Prompt:**
#
# Draft a professional email inviting colleagues to a project kickoff meeting. Include date, time, agenda, and purpose.
#
# **Refined Prompt:**
#
# Rewrite the same email in a friendly but professional tone, keep it concise, and highlight why attending is important.

# %% [markdown]
# ### Practice Using AI as Your Thought Partner
# Exercises: Try It Yourself ❗
#
# Exercise 1: Analyze a Document
#
# Choose a long document (e.g., report, article, or draft).
# Prompt AI to summarize or critique it.
#
# Example: “Summarize this 20-page report in 5 bullet points, focusing on key findings.”
#
# Answer : **Prompt:**
#
# Summarize this 20-page article into 5 clear bullet points highlighting the main arguments, evidence, and conclusions.
#
# **Refined Prompt:**
#
# Critique the same article by identifying strengths, weaknesses, and gaps in reasoning, and suggest improvements for clarity and impact.
#
# Exercise 2: Draft for a Deadline
#
# Pick an urgent task (e.g., email, proposal, or plan).
# Prompt AI to create a draft or outline.
# Example: “Draft a 200-word project summary for a client meeting tomorrow.”
#
#
# Answer : *Prompt:* Draft a concise 200-word summary of the "Atlas" software migration project for a client meeting tomorrow. Focus on completed milestones and next steps.
#
# Exercise 3: Brainstorm Ideas
#
# Choose a creative challenge (e.g., product feature, campaign idea).
# Prompt AI to suggest three ideas and explain their value.
# Example: “Propose three event ideas for a team retreat and explain their benefits.”
#
# Answer :**Prompt :**
#
# Propose three innovative features for a smartwatch focused on user health and explain their unique value.
#
# Exercise 4: Combine Analysis and Drafting
#
# Use AI to analyze a document, then draft a related output.
# Example: “Analyze this report for key trends, then draft a 100-word summary for executives.”
#
# **Original Prompt:**
#
# Analyze this report on community engagement and create a summary for a newsletter.
#
# **Refined Prompt:**
#
# Analyze the provided 25-page report on community engagement. Identify the three most significant trends or insights. Then, draft three actionable recommendations for stakeholders based on this analysis.
#
# ✅ Reflection Question 💡:
# How could enlisting AI as a thought partner help you save time, spark creativity, or improve decision-making in your workplace?
#
# Answer : AI automates routine tasks to save time and generates novel ideas to overcome creative blocks, improving both efficiency and innovation.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Pick a task (e.g., email, plan, or creative brief).
# Write a meta-prompt asking AI to generate a prompt for it.
# Example: “Generate a prompt to write a thank-you email to event attendees.”
#
# **Prompt :** Generate a prompt to write a formal project proposal for implementing a new remote work cybersecurity policy.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Choose a structured task (e.g., project plan, meeting agenda).
# Write a meta-prompt for a prompt template.
# Example: “Create a template for a prompt to plan a product launch timeline.”
#
# Answer : Create a template for a prompt to draft a project kickoff meeting agenda.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Find an image (e.g., artwork, photo) relevant to a task.
# Write a meta-prompt to generate a prompt based on it.
# Example: “Generate a prompt to create a poster inspired by this attached cityscape photo.”
#
# Answer : Generate a prompt to design a minimalist logo based on this attached image of a mountain range.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Choose a text document (e.g., article, manual).
# Write a meta-prompt to generate a prompt based on it.
# Example: “Using this attached report, generate a prompt to summarize its key findings.”
#
# ** Answer :** Using this attached user manual, generate a prompt to create a one-page quick-start guide for new customers.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Pick a complex task (e.g., proposal, campaign plan).
# Write a meta-prompt to generate a prompt for one part, then chain another for the next part.
# Example: “Generate a prompt for a campaign tagline, then one for a campaign timeline.”
#
# **Prompt :** Generate a prompt to outline the key sections of a marketing proposal, then generate a follow-up prompt to draft the executive summary for that proposal.

# %% [markdown]
# ### Prompt Refinement Strategies 🔄
#
# Exercise: Try It Yourself ❗
#
# Choose an existing prompt that gave lackluster results.
# Write a meta-prompt to improve it.
# Example: “How can I make this prompt for a team email more engaging? [Attach prompt]”
#
# **Original Prompt :** Improve this prompt: "Summarize this 30-page report." Generate a new prompt that asks AI to:
#
# Provide a structured executive summary with key findings.
#
# Extract and list actionable recommendations.
#
# Identify any data gaps or inconsistencies in the report.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Gather 2–3 prompts for the same task that didn’t work well.
# Write a meta-prompt to combine them into one.
# Example: “Combine these prompts for a meeting agenda into one clear prompt. [Attach prompts]”
#
# **Prompt :** Combine these prompts for a project status report into one clear, comprehensive prompt:
#
# 1.  "List recent project milestones."
# 2.  "What are the current risks?"
# 3.  "What are the next steps?"
#
# Generate a new single prompt that instructs the AI to create a structured status update covering: recent progress, current blockers, key risks, and next actions with owners and deadlines.
#
#
# Exercise: Try It Yourself ❗
#
# Choose a prompt with bland or off-tone results.
# Write a meta-prompt to rewrite it with a specific tone or style.
# Example: “Rewrite this prompt for a product description to be more fun and engaging. [Attach prompt]”
#
# **prompt :** Rewrite this prompt for a customer apology email to sound more empathetic and less robotic:
#
# **Original Prompt:** "Write an email to a customer about a delayed order."
#
# Generate a new prompt that instructs the AI to use a warmer, more personal tone, acknowledge the inconvenience sincerely, and clearly explain the resolution.

# %% [markdown]
# ### Practice Meta-Prompting
# Exercises: Try It Yourself ❗
#
# **Exercise 1: Direct Generation**
#
# Pick a task (e.g., writing, planning, or design).
# Write a meta-prompt to generate a prompt for it.
# Example: “Generate a prompt to write a customer thank-you email for a retail
# store
#
# **Answer :** Generate a prompt to write a formal announcement email for the launch of a new sustainability initiative at a company.
#
# **Exercise 2: Template Request**
#
# Choose a structured task (e.g., event plan, report outline).
# Write a meta-prompt for a prompt template.
# Example: “Create a template for a prompt to organize a team-building event.”
#
# **Prompt :** Create a template for a prompt to draft a quarterly business review (QBR) presentation.
#
# **Exercise 3: Prompt Refinement **
#
# Take an existing prompt with suboptimal results.
# Write a meta-prompt to improve its tone, clarity, or specificity.
# Example: “How can I improve this prompt for a social media post to be more engaging? [Attach prompt]
#
# **Prompt : ** How can I improve this prompt for a market analysis report to be more specific and data-driven?
#
# **Original Prompt:** "Write a market analysis report."
#
# Generate a revised prompt that instructs the AI to:
# - Structure the report with clear sections (e.g., Executive Summary, Market Size, Competitors, Trends, Opportunities/Risks).
# - Specify the use of quantitative data (e.g., statistics, growth rates, market share percentages).
# - Include real-world examples of key competitors and their strategies.
# - Focus on the technology sector in Southeast Asia.
#
# **Exercise 4: Meta-Prompt Chaining**
#
# Choose a complex task (e.g., proposal, campaign).
# Write a meta-prompt for one part, then chain another for the next part.
# Example: “Generate a prompt for a campaign slogan, then one for a campaign timeline.”
#
# **Prompt :** Generate a prompt to create a detailed outline for a new employee onboarding program, then generate a follow-up prompt to draft the welcome email for new hires based on that program outline.
#
# ✅ Reflection Question 💡 :
# How could meta-prompting help you craft better prompts or improve AI outputs for your specific work tasks?
#
# **Answer :** Meta-prompting helps structure requests precisely, ensuring AI outputs are targeted and high-quality. It saves time by automating prompt refinement and boosts effectiveness for complex or nuanced tasks.

# %% [markdown]
# ### Building AgentSim: A Simulation AI Agent 🎭
#
# Exercise: Try It Yourself ❗
#
# Choose a scenario (e.g., client meeting, performance review).
# Write a prompt for AgentSim to role-play, specifying the persona, conversation types, and stop phrase.
# Example: “Act as a client in a sales meeting. Support discussions on product benefits and pricing. End when I say ‘DONE.’ Provide feedback afterward.”
# Test the simulation and refine the prompt for clarity or detail.
#
# Answer  : Original Prompt:
# "Act as a junior project manager in a post-project review meeting. Respond to questions about timeline delays and budget management. End when I say END_ROLEPLAY. Provide feedback afterward."
#
# Refined Prompt:
# "Role-play as a junior project manager in a post-project review. Respond professionally to questions about timeline delays and budget overruns. Stop when I say END_ROLEPLAY. Afterward, give three bullet points of feedback on my leadership communication."
#
# Key Improvements:
#
# Clarity: Simplified language and removed ambiguity.
#
# Focus: Specified "budget overruns" instead of vague "budget management."
#
# Structure: Explicitly requested three bullet points for actionable feedback.
#
# Brevity: Made the prompt more concise while retaining critical details.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Choose a work output (e.g., report, presentation, or plan).
# Write a prompt for AgentX to provide feedback, specifying the expertise and focus areas.
# Example: “Act as a project management consultant. Review my project plan and suggest improvements for timeline and resource allocation.”
# Use the feedback to improve your work and refine the prompt if needed.
#
# Amswer : Original Prompt:
# "Act as a project management consultant. Review my project plan and suggest improvements for timeline and resource allocation."
#
# Refined Prompt:
# "Role-play as a project management expert. Critique my project plan’s timeline and resource allocation. Suggest 3 concise improvements. Stop when I say END."
#
# Why refined:
#
# Shorter, clearer role ("expert").
#
# Specific focus ("timeline, resource allocation").
#
# Exact output request ("3 concise improvements").
#
# Controlled end (END).

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Write a meta-prompt to generate or refine a prompt for AgentSim or AgentX.
# Example: “Generate a prompt for an AI agent to simulate a team meeting discussion on project priorities.”
# Test the generated prompt and refine it if needed.
#
# Answer : Meta-Prompt:
# "Generate a prompt for an AI agent (AgentSim) to simulate a team meeting where a project manager discusses shifting priorities with skeptical team members. Specify:
#
# The agent’s role (e.g., senior developer).
#
# Key conversation topics (e.g., timeline impact, morale).
#
# Desired tone (professional but resistant).
#
# Stop phrase (END_SIM).
#
# Request feedback on the manager’s persuasion tactics after the simulation."
#
# Generated Prompt (from AgentSim):
# "Role-play as a senior developer in a project meeting. Respond skeptically to the project manager’s request to reprioritize tasks, citing concerns about timeline delays and team burnout. Keep responses concise and realistic. End the simulation when the manager says END_SIM. Afterward, provide brief feedback on the manager’s persuasion strategies."
#
# Refined Generated Prompt :
# "Simulate a senior developer resisting project priority changes. Discuss timeline and burnout concerns. Stop at END_SIM. Then give feedback on the manager’s approach."
#
# Testing & Refinement:
#
# Tested: AgentSim responded with realistic skepticism but was too verbose.
#
# Refined: Added "Keep responses concise" to the prompt for tighter dialogue.
#
# Why It Works:
#
# Clear role, goals, and constraints.
#
# Balances realism with brevity.
#
# Links simulation to actionable feedback.

# %% [markdown]
# ### Practice Building AI Agents
# Exercises: Try It Yourself ❗
#
# Exercise 1: Create AgentSim
# Choose a scenario (e.g., job interview, client pitch).
# Write a prompt for AgentSim to role-play, including a stop phrase and feedback.
# Example: “Act as a client in a product demo. Discuss features and pricing. End when I say ‘THANKS.’ Provide feedback.”
#
# **Prompt for AgentSim:**
# "Act as a hiring manager for a tech startup. Role-play a job interview for a Data Analyst position. Ask questions about technical skills (e.g., SQL, Python), problem-solving, and past projects. Respond naturally to my answers. End the simulation when I say END_INTERVIEW. Afterward, provide 3 bullet points of constructive feedback on my interview responses and overall presentation."
#
# Stop Phrase:
# END_INTERVIEW
#
# Feedback Request:
# Brief, actionable feedback on clarity, relevance, and professionalism of answers.

# %% [markdown]
# Exercise 2: Create AgentX
#
# Pick a work output (e.g., code, design, or plan).
# Write a prompt for AgentX to provide expert feedback.
# Example: “Act as a UX design expert. Review my app prototype and suggest improvements for usability.
#
# **Prompt for AgentX:**
#
# "Act as a senior software engineer. Review my Python code for efficiency, best practices, and error handling. Give 3 concise improvements. Stop at END."
#
# Exercise 3: Use Meta-Prompting
#
# Write a meta-prompt to generate or refine a prompt for AgentSim or AgentX.
# Example: “Generate a prompt for an AI agent to simulate a performance review discussion.”
#
#  Answer : Meta-Prompt:
# "Generate a prompt for AgentSim to simulate a performance review where a manager discusses both strengths and areas for improvement with an employee. Include:
#
# Role (e.g., employee)
#
# Key topics (e.g., recent achievements, skill gaps)
#
# Stop phrase (END_REVIEW)
#
# Request feedback on the manager’s delivery."
#
# Generated Prompt :
# "Role-play as an employee during a performance review. Respond to feedback on your achievements and areas to improve. Keep replies professional. Stop at END_REVIEW. After, suggest how the manager could improve their feedback delivery.
#
# Exercise 4: Combine Simulation and Feedback
#
# Use AgentSim to practice a scenario, then AgentX to review your performance.
# Example: “Simulate a client meeting, then provide feedback as a sales coach.”
#
#  Answer : AgentSim Prompt (Simulation):
#
# "Role-play as a hesitant client in a sales meeting. Question the product’s cost and suitability. Keep responses short. End when I say END_MEETING."
#
# AgentX Prompt (Feedback):
#
# "Act as a sales coach. Review the client meeting simulation. Provide 3 bullet points on how to better handle pricing objections and build trust. Stop at END_FEEDBACK."
#
# Why it works:
#
# Simulation (AgentSim) mimics real interaction.
#
# Feedback (AgentX) gives targeted, expert advice.
#
# Clear stop phrases (END_MEETING, END_FEEDBACK) control flow.
#
# Concise and actionable for quick improvement.
#
# ✅ Reflection Question 💡:
# How could AI agents like AgentSim and AgentX help you practice skills or improve work outputs in your role?
#
# Answer : **AgentSim** lets me practice tough conversations (like feedback or negotiations) safely, while **AgentX** gives expert advice to refine my work (like code or strategy) faster. Together, they accelerate skill-building and output quality.

# %% [markdown]
# ### Building AgentX: Your Expert Feedback AI Agent 🛠️
#
# Exercise: Try It Yourself ❗
#
# Choose a work output (e.g., pitch, report, or design).
# Write a prompt for AgentX to critique it, specifying the persona, focus areas, and a stop phrase.
# Example: “Act as a marketing executive. Review my ad campaign draft, focusing on messaging and visuals. Continue until I say ‘DONE.’ Provide a summary afterward.”
# Test the feedback and refine the prompt for more specificity if needed.
#
# Answer : **Prompt for AgentX:**
#
# "Act as a senior marketing director. Critique my email campaign draft below. Focus on:
#
# Clarity of the call-to-action
#
# Tone and engagement
#
# Mobile readability
# Provide 3 concise improvements. Stop when I say END_FEEDBACK."

# %% [markdown]
# ### Practice Building AgentX
# Exercises: Try It Yourself ❗
#
# Exercise 1: Create AgentX for Feedback
#
# Choose a work output (e.g., proposal, design, or code).
# Write a prompt for AgentX to critique it, specifying the persona and focus areas.
# Example: “Act as a content strategist. Review my blog post draft for clarity and engagement. Continue until I say ‘FINISH.’ Provide a summary.”
#
#  prompt : **AgentX Prompt:**
# "Act as a senior content strategist. Critique my blog post for hook, readability, and SEO. Suggest 3 edits. Stop at **END**."
#
#
# Exercise 2: Refine with Meta-Prompting
#
# Take a vague prompt for AgentX that didn’t work well.
# Write a meta-prompt to improve it.
# Example: “How can I improve this prompt to get better feedback on my marketing plan? [Attach prompt]”
#
# **prompt : Vague Prompt:**
# "Review my marketing plan."
#
# **Meta-Prompt:**
#
# "Improve this AgentX prompt: 'Review my marketing plan.' Make it specify:
#
# Persona (e.g., digital marketing expert)
#
# Focus areas (e.g., target audience, budget, channels)
#
# Output (e.g., 3 actionable tips)
#
# Stop phrase (END)"
#
# **Refined Prompt:**
#
# "Act as a digital marketing expert. Review my marketing plan for target audience alignment, budget efficiency, and channel selection. Give 3 actionable tips. Stop at END.
#
# Exercise 3: Use Context for Feedback
#
# Attach or describe a specific document (e.g., brief, draft).
# Write a prompt for AgentX to critique it using the context.
#
# Answer : Document:
# [Attached: Draft email campaign for product launch]
#
# Prompt for AgentX:
# "Act as a senior marketing director. Review the attached email draft. Focus on:
#
# Call-to-action clarity
#
# Tone and brand voice
#
# Mobile formatting
# Give 3 concise improvements. Stop at END."
#
# Exercise 4: Iterate Feedback
#
# Use AgentX to critique a draft, revise it, then ask AgentX to review the revised version.
#
# Answer : **First:**
# "Review my sales pitch. Suggest 3 fixes. Stop at **END**."
#
# **After Revision:**
# "Check my revised pitch. Are the fixes done? Suggest one more improvement. Stop at **END**."
#
# ✅ Reflection Question 💡 :
# How could AgentX’s expert feedback help you improve specific work outputs or prepare for high-stakes scenarios in your role?
#
# Answer : AgentX provides expert-level critiques to refine key outputs (pitches, reports, code) efficiently, ensuring higher quality and confidence before real-world use. It accelerates iteration and reduces oversight risks.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Choose a work output (e.g., report, design, code).
# Write a prompt for an AI agent to critique it, specifying expertise and criteria.
# Example: “Act as a UX designer. Critique my app wireframe for usability. End with ‘DONE.’”
#
# Answer : **Prompt for AI Agent:**
#
# "Act as a senior UX designer. Critique my app wireframe for usability, accessibility, and visual hierarchy. Provide 3 actionable improvements. Stop at DONE.

# %% [markdown]
# Exercise: Try It Yourself ❗
#
# Choose a new skill or topic (e.g., coding, marketing).
# Write a prompt for an AI agent to teach it with lessons and feedback.
# Example: “Act as a Python tutor. Teach me basic coding with exercises. End with ‘CODE OFF.’”
#
# Answer : Prompt for AI Agent:
#
# "Act as a digital marketing tutor. Teach me SEO basics with 3 short lessons and a practical task. Give feedback on my answers. Stop at END."

# %% [markdown]
# ### Practice Building AI Agents
#
# Exercises: Try It Yourself ❗
#
# Exercise 1: Skill Practice Agent
# Choose a skill (e.g., negotiation, presenting).
# Write a prompt for an AI agent to role-play and provide feedback.
# Example: “Act as a sales coach. Role-play a client pitch and critique my performance. End with ‘SOLD.’”
#
#   Prompt for AI Agent:
# "Act as a negotiation coach. Role-play a salary discussion and critique my approach. Focus on clarity, confidence, and counterpoints. Give 3 improvements. Stop at END."
#
# Exercise 2: Feedback Agent
#
# Pick a work output (e.g., writing, design).
# Write a prompt for an AI agent to critique it.
# Example: “Act as an editor. Critique my article for clarity and tone. End with ‘PUBLISH.’”
#
# **prompt :** "Act as an editor. Review my article for clarity and tone. Suggest 3 fixes. Stop at **END**."
#
# Exercise 3: Learning Agent
#
# Choose a new skill or topic (e.g., language, software).
# Write a prompt for an AI agent to teach it with lessons and quizzes.
# Example: “Act as a data analysis tutor. Teach me Excel basics with exercises. End with ‘LESSON OVER.’”
#
# **Prompt:** Act as a Spanish tutor. Teach me beginner phrases with examples and a quiz. Correct my answers. Stop at **END**.
#
# Exercise 4: Collaboration Agent
#
# Pick a project task (e.g., proposal, plan).
# Write a prompt for an AI agent to collaborate on it.
# Example: “Act as a project manager. Help me draft a project timeline. End with ‘COMPLETE.’”
# Answer : "Act as a project manager. Help me outline a project plan with tasks, deadlines, and owners. Stop at **DONE**."
#
# ✅ Reflection Question 💡:
# How could AI agents help you tackle specific challenges or achieve goals in your work or personal life?
#
# Answer : AI agents can act as on-demand experts, providing instant feedback, simulating real-world scenarios for practice, and accelerating skill development—turning obstacles into opportunities efficiently.They save time, reduce errors, and boost confidence in high-stakes situations.

# %% [markdown]
# ### Practice Building Your Prompt Library
# Exercises: Try It Yourself ❗
#
# Exercise 1: Create a Communication Prompt
# Choose a communication task (e.g., email, announcement).
# Write a prompt and save two versions (e.g., formal vs. casual).
# Example: “Write a customer email for a product recall (v1: formal, v2: empathetic).”
#
# **v1 (Formal):**
# "Write a formal product recall email with details and instructions."
#
# **v2 (Empathetic):**
# "Write a compassionate recall email focusing on apology and customer care."
#
# Exercise 2: Create a Content Prompt
#
# Pick a content task (e.g., FAQ, social media post).
# Write a prompt and version it for different audiences.
# Example: “Create 5 FAQs for consumers (v1) and businesses (v2) based on this product.”
# **v1 (Consumers):**
# "Create 5 consumer FAQs for a new smartwatch. Focus on setup, daily use, and troubleshooting."
#
# **v2 (Businesses):**
# "Create 5 business FAQs for the same smartwatch. Focus on bulk orders, security, and enterprise integration."
#
# **Why version both:**
# - Tailors language, depth, and priorities to each audience.
# - Ensures relevance (e.g., consumers care about ease, businesses care about scalability).
#
# Exercise 3: Use Meta-Prompting
#
# Write a meta-prompt to generate or refine a prompt for your library.
# Example: “Generate a prompt for a project status report with a clear, professional tone.”
#
# Answer : **Meta-Prompt:**
# "Generate a prompt to write a project status report. Ensure it includes:
#
# Key sections (progress, risks, next steps)
#
# Professional tone
#
# Length: 1 page
#
# Specify the audience: internal team"
#
# ***Generated Prompt:***
# "Draft a one-page project status report for the internal team. Cover progress, current risks, and next steps. Use a clear, professional tone."
#
# **Refined :**
# "Write a concise project status report for internal team: progress, risks, next steps. Keep it professional and to one page."
#
# Exercise 4: Organize Your Library
#
# Create a spreadsheet or document with 3–5 prompts, categorized by use case.
# Add notes on tone, audience, and effectiveness.
#
# **Prompt Library  **
#
# | **Category**       | **Prompt**                                                                 | **Tone**       | **Audience**       | **Effectiveness**				|
# |---------------------|---------------------------------------------------------------------------|----------------|--------------------|-------------------------------|
# | **Email**          | "Draft a polite payment reminder email to a client."                     | Professional  | Clients            | Clear, gets quick responses.  |
# | **Social Media**   | "Create a catchy Instagram post for a coffee shop launch."               | Friendly      | Young adults       | High engagement.              |
# | **Reporting**      | "Summarize weekly team progress in 3 bullet points for managers."        | Concise       | Internal leaders   | Saves time, highlights key issues. |
#
# **Why organize:**
# - Quickly find the right prompt for the task.
# - Ensure consistency in tone and messaging.
# - Track which prompts deliver the best results.
#
# ✅ Reflection Question 💡:
# How could a prompt library help you streamline repetitive tasks or improve AI outputs in your work?
#
# Answer : A prompt library saves time by providing reliable, pre-tested templates for repetitive tasks (emails, reports, social posts), ensuring consistent quality, tone, and structure—while reducing guesswork and iteration. It turns one-off efforts into reusable assets.

# %% [markdown]
# ## NOTEBOOK # 04 SOLUTION :
#
# ## 🚀 This assignment will be your 1st month Project
#
# But first i want you to give me a recap of your learning
#
# Give a recap of notebook
#
# 👉 First notebook provide  a complete 5-step framework for crafting effective AI prompts to generate high-quality text and image outputs.It emphasizes the importance of iteration, adding specific details, and using the outputs responsibly.
#
# Give a recap of notebook 2
#
# 👉 This guide shows us how to use Ai for  daily work jobs. It teaches us to write good prompts to make emails,plan projects, create schedules, and shorten long documents fast
#
# Give a recap of notebook 3
#
# 👉 This guide explains how to use AI as a creative partner for complex tasks by building specialized agents and a library of effective prompts.It covers advanced techniques like prompt chaining to simulate scenarios and get expert feedback.

# %% [markdown]
# ### Eco-Guide: Sustainable Living Assistant – Project Report
# ### 1. Use Case
#
# I chose to build a Sustainable Living Assistant chatbot, named Eco-Guide.
#
# Why this use case?
#
# Many individuals want to adopt a more sustainable lifestyle but are overwhelmed by the complexity, conflicting information, and lack of personalized guidance. A chatbot can demystify sustainability by providing instant, accessible, and tailored advice, making eco-friendly choices easier for everyone.
#
# **Target Users:**
#
# Environmentally conscious individuals and families.
#
# People new to sustainability ("zero-waste curious").
#
# Students and educators researching environmental topics.
#
# Small business owners looking to improve their green credentials.
#
# **Expected Benefits:**
#
# Provides personalized, actionable steps to reduce one's carbon footprint.
#
# Offers a judgment-free space to ask "basic" questions about sustainability.
#
# Helps users find local recycling, composting, and repair options.
#
# Educates users on the environmental impact of daily choices.
#
# **Limitations:**
#
# Cannot provide real-time, hyper-local information (e.g., exact bin collection times).
#
# Advice is general and may not account for all regional regulations or infrastructure.
#
# Cannot perform complex life-cycle assessments for products.
#
# ### 2. Justification
#
# **Why is this problem worth solving?**
#
# Climate anxiety is widespread, and people often don't know where to start. This bot empowers users by breaking down a monumental challenge into small, manageable, and personalized actions, turning anxiety into agency.
#
# **Why a chatbot instead of apps/websites/humans?**
#
# More interactive than a static website: It provides a two-way dialogue, unlike a blog or FAQ page.
#
# More accessible than an app: No download required; it can be integrated into existing messaging platforms.
#
# More scalable and available than a human expert: Provides 24/7 instant access to a vast knowledge base without scheduling a consultant.
#
# # **Specific tasks the bot will perform:**
#
# Recommend ways to reduce waste at home (e.g., food, plastic, energy).
#
# Explain how to properly recycle or compost specific items.
#
# Suggest sustainable alternatives to everyday products.
#
# Provide simple, eco-friendly recipes for homemade cleaning supplies.
#
# Offer tips for sustainable shopping and consumption.
#
# ### 3. LLM Choice (Groq)
#
# I chose the Mixtral-8x7b-32768 model on Groq.
#
# Why this model fits the use case:
#
# **Reasoning Capability (Size): **Sustainability questions often require balancing multiple factors (e.g., cost, convenience, environmental impact). Mixtral's Mixture-of-Experts architecture is excellent at handling such multi-faceted reasoning compared to a smaller 8B model.
#
# **Broad Knowledge Base:** The 7B parameter experts within Mixtral provide a wide knowledge base, crucial for answering diverse questions about materials, practices, and environmental science.
#
# **Context Window (32768 tokens):** This large context is ideal for providing detailed, step-by-step guides (e.g., a recipe for homemade laundry detergent) without losing the thread of the conversation.
#
# **Speed:** While slightly larger, Groq's LPU handles Mixtral with incredible speed, ensuring a fluid and real-time conversational experience.
#
# **4. Conversation Flow**
#
# **Sample Dialogues:**
#
# **Greeting**
#
# User: “Hi”
#
# Bot: “Hello! I'm Eco-Guide, your assistant for sustainable living. What would you like to work on today? You can ask me about recycling, reducing waste, eco-friendly swaps, and more!”
#
# **Recycling Guidance**
#
# User: “Can I recycle pizza boxes?”
#
# Bot: “It depends! If the box is greasy or has cheese stuck to it, it can contaminate a paper recycling batch. Your best bet is to tear off the clean lid for recycling and compost or trash the greasy bottom part.”
#
# **Sustainable Swap**
#
# User: “What's a good alternative to plastic wrap?”
#
# Bot: “Great question! A popular swap is beeswax wraps. They're reusable, made from natural materials, and perfect for covering bowls and wrapping food. You can also use reusable silicone lids or simply put a plate on top of a bowl.”
#
# **Unknown Question**
#
# User: “What's the capital of France?”
#
# Bot: “I'm sorry, I'm specifically designed to help with questions about sustainable living, like recycling, reducing waste, and eco-friendly habits. Is there something I can help you with in that area?”
#
# **Goodbye**
#
# User: “Thanks, that's all for now!”
#
# Bot: “You're welcome! Every small change makes a big difference. Come back anytime you have more questions on your sustainability journey!”
#
# **Memory Rules:**
#
# Short-term context memory: It will remember the current conversation thread (e.g., if a user is asking follow-up questions about composting).
#
# No long-term memory: It will not remember a user's name or past conversations to ensure privacy and simplicity.
#
# ### CODE FOR CHATBOT :

# %%
# 🌿 Eco-Guide: Sustainable Living Assistant Chatbot

# Install required library
# !pip install groq

# Import necessary modules
from groq import Groq
import getpass
import sys

# --- CONFIGURATION ---
# Initialize the Groq client with your API Key
print("Please enter your Groq API key to continue. (Your typing will be hidden)")
api_key = getpass.getpass('Groq API key...: ').strip()

if not api_key:
    print("Error: No API key provided. Exiting.")
    sys.exit(1)

try:
    client = Groq(api_key=api_key)
    # Test the connection with a simple request
    test_completion = client.chat.completions.create(
        messages=[{"role": "user", "content": "Hello"}],
        model="llama-3.1-8b-instant",  # Using a currently available model
        max_tokens=5,
    )
    print("API connection successful!")
except Exception as e:
    print(f"Failed to initialize Groq client: {e}")
    print("Please check your API key and try again.")
    sys.exit(1)

# Define the AI model - using a currently available model
MODEL_NAME = "llama-3.1-8b-instant"  # Updated to a currently supported model

# Alternative models you could try:
# - "llama-3.1-70b-versatile"
# - "llama-3.1-8b-instant"
# - "mixtral-8x7b-32768" (if it becomes available again)
# - "gemma2-9b-it"

SYSTEM_PROMPT = """
You are 'Eco-Guide', a friendly and knowledgeable Sustainable Living Assistant.
Your goal is to provide practical, actionable, and non-judgmental advice to help users live more eco-friendly lives.
You specialize in:
- Waste reduction (food, plastic, etc.)
- Recycling and composting guidelines
- Sustainable product alternatives and DIY solutions
- General education on environmental impact

Always be encouraging and focus on progress, not perfection. If a user asks about something outside your scope (like math or movies), politely decline and steer the conversation back to sustainability.
If a question is complex, break it down into clear, step-by-step instructions.
"""

# --- MAIN CHAT FUNCTION ---
def run_eco_guide():
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
    ]

    print("\n" + "="*50)
    print("🌿 Welcome to Eco-Guide! Your Sustainable Living Assistant.")
    print("Let's talk about recycling, reducing waste, and eco-friendly swaps!")
    print("Type 'quit' at any time to end the conversation.")
    print("="*50 + "\n")

    while True:
        user_input = input("You: ").strip()

        if not user_input:
            continue

        if user_input.lower() == 'quit':
            print("\nEco-Guide: Thanks for chatting! Remember, every small change helps. 🌎")
            break

        messages.append({"role": "user", "content": user_input})

        try:
            chat_completion = client.chat.completions.create(
                messages=messages,
                model=MODEL_NAME,
                temperature=0.5,
                max_tokens=1024,
            )

            ai_response = chat_completion.choices[0].message.content
            print(f"\nEco-Guide: {ai_response}\n")
            messages.append({"role": "assistant", "content": ai_response})

        except Exception as e:
            print(f"\nSorry, I encountered an error: {e}")
            print("This might be due to an invalid API key or model availability issues.")
            break


run_eco_guide()
# Out:
# ...
# Please enter your Groq API key to continue. (Your typing will be hidden)
# Enter your Groq API key: ··········
# API connection successful!
#
# ...
# 🌿 Welcome to Eco-Guide! Your Sustainable Living Assistant.
# Let's talk about recycling, reducing waste, and eco-friendly swaps!
# Type 'quit' at any time to end the conversation.
# ...
#
# You: hi  tell me how we can manage the recycling
#
# Eco-Guide: Managing recycling can be a bit overwhelming at first, but don't worry, I'm here to help you simplify it.
#
# Let's break it down into some easy-to-follow steps:
#
# 1. **Know your local recycling guidelines**: Check with your local waste management agency or municipality to learn what materials are accepted in your curbside recycling program. You can usually find this information on their website or by calling them directly.
# ...

# %% [markdown]
# ### 5. Prompting Technique
# I will use a combination of:
#
# System Prompt Persona: To firmly establish the bot's role, knowledge boundaries, and tone (friendly, encouraging, and practical).
#
# Few-shot Prompting: To prime the model with examples of high-quality, actionable responses for common queries.
#
# Chain-of-thought prompting: For questions that require a multi-step explanation (e.g., "How do I start a compost bin?").
